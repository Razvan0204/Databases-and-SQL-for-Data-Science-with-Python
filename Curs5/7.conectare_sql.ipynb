# %%
import mysql.connector

# %%
cnx = mysql.connector.connect(
    host="127.0.0.1",
    port=3306,
    user="root",
    password="root1234")

# %%
cur = cnx.cursor()

# %%
cur.execute("SHOW DATABASES")

# %%
for db in cur:
    print(db)
# Out:
# ('a_treia_baza_de_date',)
# ('angajati',)
# ('baza_de_date_4',)
# ('facultate',)
# ('geografie',)
# ('information_schema',)
# ('masini furate',)
# ('mydb',)
# ('mysql',)
# ('online_store',)
# ('performance_schema',)
# ('personal',)
# ('prima_baza_de_date',)
# ('python_created_db',)
# ('sakila',)
# ('sys',)
# ('universitate',)
# ('vremea',)
# ('world',)

# %%
cur.execute('USE universitate')

# %%
cur.execute('INSERT INTO profesor SET nume="Guido", prenume="Van Rossum", data_nasterii="1956-01-31", adresa_idadresa=1')

# %%
cur.execute('SELECT * FROM profesor')
for prof in cur:
    print(prof)
# Out:
# (1, 'Popescu', 'Gica', 1, datetime.date(1964, 2, 1), 'I')
# (2, 'Marin', 'Andreea', 1, datetime.date(1989, 12, 30), 'II')
# (3, 'Florescu', 'Florina', 1, datetime.date(1989, 12, 10), 'II')
# (4, 'Ionescu', 'Ioan', 1, datetime.date(1969, 12, 9), 'III')
# (5, 'Marinescu', 'Marin', 1, datetime.date(1990, 10, 30), 'II')
# (6, 'Jelsma', 'GÃ¼lten', 1, datetime.date(1994, 1, 11), 'I')
# (7, 'Garrido', 'Alejandro', 1, datetime.date(1995, 3, 27), 'I')
# (8, 'Langeveld', 'Alkan', 1, datetime.date(1966, 12, 22), 'I')
# (9, 'Sturm', 'Henrick', 1, datetime.date(1995, 12, 9), 'I')
# (10, 'Ø³Ù„Ø·Ø§Ù†ÛŒ Ù†Ú˜Ø§Ø¯', 'Ø§Ø·Ù…Ù‡ Ø²Ù‡Ø±Ø§', 1, datetime.date(1959, 10, 26), 'I')
# (11, 'Larson', 'Danny', 1, datetime.date(1966, 3, 31), 'I')
# (12, 'Mugeraya', 'Balendra', 1, datetime.date(1964, 8, 26), 'I')
# (13, 'Patel', 'Nevaeh', 1, datetime.date(1986, 1, 22), 'I')
# (14, 'Ä†irkoviÄ‡', 'Silvija', 1, datetime.date(1967, 10, 19), 'I')
# (15, 'Moura', 'Pedrino', 1, datetime.date(1953, 2, 16), 'I')
# (16, 'Guido', 'Van Rossum', 1, datetime.date(1956, 1, 31), 'I')

# %%
cnx.commit()

# %%
cur.close()
cnx.close()
